# %%
# the datasets is circket to predict the future trends.
import pandas as pd

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.getcwd()
# Out:
# 'D:\\Data Science Certification\\Module 2\\Homework'

# %% [markdown]
# ### Read CSV File into a DataFrame

# %%
data=pd.read_csv('Cricket.csv')
##Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns',None)
#Set it to None to display all rows in the dataframe
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#    ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0                0  Summer       New Zealand   New Zealand      Wellington
# 1                0  Summer       New Zealand  South Africa      Queenstown
# 2                0  Summer       New Zealand   New Zealand    Christchurch
# 3                1  Summer       New Zealand   New Zealand          Napier
# 4                2  Summer       New Zealand   New Zealand        Hamilton
# 5                3  Summer       New Zealand   New Zealand        Auckland
# 6                0  Winter            Others      SriLanka      Hambantota
# 7                1  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8                2  Spring            Others      SriLanka   Colombo (RPS)
# 9                3  Autumn       New Zealand      SriLanka       Pallekele
# 10               A  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ConsecutiveWins       95 non-null     object
#  1   Season                94 non-null     object
#  2   Opposition_Others     94 non-null     object
#  3   Country               95 non-null     object
#  4   Ground                95 non-null     object
#  5   Home_Ground           94 non-null     object
#  6   Day_Night             95 non-null     object
#  7   PitchReport           95 non-null     object
#  8   BattingFirst          94 non-null     object
#  9   Combination Changed   12 non-null     object
#  10  Pak_Win               94 non-null     object
# dtypes: object(11)
# memory usage: 8.3+ KB

# %%
data.dtypes
# Out:
# ConsecutiveWins         object
# Season                  object
# Opposition_Others       object
# Country                 object
# Ground                  object
# Home_Ground             object
# Day_Night               object
# PitchReport             object
# BattingFirst            object
# Combination Changed     object
# Pak_Win                 object
# dtype: object

# %% [markdown]
# ### Handle Run Time Incorrect values

# %%
missing=['A','B']
data=pd.read_csv('Cricket.csv',na_values=missing)
##Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns',None)
#Set it to None to display all rows in the dataframe
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0               0.0  Summer       New Zealand   New Zealand      Wellington
# 1               0.0  Summer       New Zealand  South Africa      Queenstown
# 2               0.0  Summer       New Zealand   New Zealand    Christchurch
# 3               1.0  Summer       New Zealand   New Zealand          Napier
# 4               2.0  Summer       New Zealand   New Zealand        Hamilton
# 5               3.0  Summer       New Zealand   New Zealand        Auckland
# 6               0.0  Winter            Others      SriLanka      Hambantota
# 7               1.0  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8               2.0  Spring            Others      SriLanka   Colombo (RPS)
# 9               3.0  Autumn       New Zealand      SriLanka       Pallekele
# 10              NaN  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
print(data.isnull().sum())
# Out:
# ConsecutiveWins          2
# Season                   1
# Opposition_Others        1
# Country                  0
# Ground                   0
# Home_Ground              1
# Day_Night                0
# PitchReport              0
# BattingFirst             1
# Combination Changed     83
# Pak_Win                  1
# dtype: int64

# %%
data.dtypes
# Out:
# ConsecutiveWins         float64
# Season                   object
# Opposition_Others        object
# Country                  object
# Ground                   object
# Home_Ground              object
# Day_Night                object
# PitchReport              object
# BattingFirst             object
# Combination Changed      object
# Pak_Win                  object
# dtype: object

# %%
print(data['Combination Changed '].isnull().sum())
# Out:
# 83

# %%
print(data['Pak_Win'].isnull().sum())
# Out:
# 1

# %%
List=['Yes','No',np.nan]

# %%
cnt=0
for row in data['Pak_Win']:
    if row in List:
        cnt+=1
        pass
    else:
        data.loc[cnt,'Pak_Win']=np.nan 
        cnt+=1

# %%
for row in data['Pak_Win']:
    if row in List:
        print("data is valid") 
    else:
        print("data is invalid")
# Out:
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# data is valid
# ...

# %%
print(data['Pak_Win'].isnull().sum())
# Out:
# 3

# %%
print(data.isnull().sum())
# Out:
# ConsecutiveWins          2
# Season                   1
# Opposition_Others        1
# Country                  0
# Ground                   0
# Home_Ground              1
# Day_Night                0
# PitchReport              0
# BattingFirst             1
# Combination Changed     83
# Pak_Win                  3
# dtype: int64

# %%
print(data.isnull().sum().sum())
# Out:
# 92

# %%
df2=data.copy()

# %%
data.dropna(['Combination Changed '],inplace=True)
#data.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-0c18a11e352d> in <module>
# ----> 1 data.dropna(['Combination Changed '],inplace=True)
#       2 #data.reset_index(drop=True, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4987         if isinstance(axis, (tuple, list)):
#    4988             # GH20987
# -> 4989             raise TypeError("supplying multiple axes to axis is no longer supported.")
#    4990
#    4991         axis = self._get_axis_number(axis)
#
# TypeError: supplying multiple axes to axis is no longer supported.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ConsecutiveWins       11 non-null     float64
#  1   Season                11 non-null     object
#  2   Opposition_Others     11 non-null     object
#  3   Country               11 non-null     object
#  4   Ground                11 non-null     object
#  5   Home_Ground           11 non-null     object
#  6   Day_Night             11 non-null     object
#  7   PitchReport           11 non-null     object
#  8   BattingFirst          11 non-null     object
#  9   Combination Changed   11 non-null     object
#  10  Pak_Win               11 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 1.1+ KB

# %%
df2
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0               0.0  Summer       New Zealand   New Zealand      Wellington
# 1               0.0  Summer       New Zealand  South Africa      Queenstown
# 2               0.0  Summer       New Zealand   New Zealand    Christchurch
# 3               1.0  Summer       New Zealand   New Zealand          Napier
# 4               2.0  Summer       New Zealand   New Zealand        Hamilton
# 5               3.0  Summer       New Zealand   New Zealand        Auckland
# 6               0.0  Winter            Others      SriLanka      Hambantota
# 7               1.0  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8               2.0  Spring            Others      SriLanka   Colombo (RPS)
# 9               3.0  Autumn       New Zealand      SriLanka       Pallekele
# 10              NaN  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
data.isnull().sum()
# Out:
# ConsecutiveWins         0
# Season                  0
# Opposition_Others       0
# Country                 0
# Ground                  0
# Home_Ground             0
# Day_Night               0
# PitchReport             0
# BattingFirst            0
# Combination Changed     0
# Pak_Win                 0
# dtype: int64

# %%
data.describe()
# Out:
#        ConsecutiveWins
# count        11.000000
# mean          1.000000
# std           1.414214
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.500000
# max           4.000000

# %% [markdown]
# ### Changing Data Types

# %%
data['ConsecutiveWins']=data['ConsecutiveWins'].astype(int)
data['ConsecutiveWins'].dtypes
# Out:
# dtype('int32')

# %%
data['Country']=data['Country'].astype('category')
data['Country'].dtypes
# Out:
# CategoricalDtype(categories=['Bandladesh', 'New Zealand', 'South Africa', 'SriLanka',
#                   'UAE', 'Zimbabwe'],
#                  ordered=False)

# %%
#ddata['Season']=data['Season'].astype('category')
#data['Season'].dtypes

# %%
data['Ground']=data['Ground'].astype('category')
data['Ground'].dtypes
# Out:
# CategoricalDtype(categories=['Abu Dhabi', 'Auckland', 'Christchurch', 'Colombo (RPS)',
#                   'Dhaka', 'Hambantota', 'Hamilton', 'Harare', 'Napier',
#                   'Queenstown', 'Wellington'],
#                  ordered=False)

# %%
data['Opposition_Others']=data['Opposition_Others'].astype('category')
data['Opposition_Others'].dtypes
# Out:
# CategoricalDtype(categories=['Bangladesh', 'New Zealand', 'Others', 'South Africa',
#                   'Sri Lanka', 'Zimbabwe'],
#                  ordered=False)

# %%
data['Pak_Win'] = np.where(data['Pak_Win']=="Yes",True,False)

# %%
data['BattingFirst'] = np.where(data['BattingFirst']=="Yes",True,False)

# %%
data['Day_Night']= np.where(data['Day_Night']=="Yes",True,False)

# %%
data['Home_Ground']= np.where(data['Home_Ground']=="Yes",True,False)

# %%
data['Combination Changed ']= np.where(data['Combination Changed ']=="Yes",True,False)

# %%
data.dtypes
# Out:
# ConsecutiveWins            int32
# Season                    object
# Opposition_Others       category
# Country                 category
# Ground                  category
# Home_Ground                 bool
# Day_Night                   bool
# PitchReport               object
# BattingFirst                bool
# Combination Changed         bool
# Pak_Win                     bool
# dtype: object

# %%
data.describe(include=['object','bool'])
# Out:
#         Season Home_Ground Day_Night PitchReport BattingFirst  \
# count       11          11        11          11           11
# unique       3           1         2           3            2
# top     Summer       False      True      bouncy         True
# freq         6          11         8           7            8
#
#        Combination Changed  Pak_Win
# count                    11      11
# unique                    2       2
# top                   False    True
# freq                      9       7

# %%
data.describe(include=['category','bool'])
# Out:
#        Opposition_Others      Country      Ground Home_Ground Day_Night  \
# count                 11           11          11          11        11
# unique                 6            6          11           1         2
# top          New Zealand  New Zealand  Wellington       False      True
# freq                   6            5           1          11         8
#
#        BattingFirst Combination Changed  Pak_Win
# count            11                   11      11
# unique            2                    2       2
# top            True                False    True
# freq              8                    9       7

# %%
data
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country         Ground  \
# 0                 0  Summer       New Zealand   New Zealand     Wellington
# 1                 0  Summer       New Zealand  South Africa     Queenstown
# 2                 0  Summer       New Zealand   New Zealand   Christchurch
# 3                 1  Summer       New Zealand   New Zealand         Napier
# 4                 2  Summer       New Zealand   New Zealand       Hamilton
# 5                 3  Summer       New Zealand   New Zealand       Auckland
# 6                 0  Winter            Others      SriLanka     Hambantota
# 7                 1  Winter         Sri Lanka      SriLanka  Colombo (RPS)
# 8                 4  Spring          Zimbabwe      Zimbabwe         Harare
# 9                 0  Spring        Bangladesh    Bandladesh          Dhaka
# 10                0  Spring      South Africa           UAE      Abu Dhabi
#
# ...

# %% [markdown]
# ### Univariates categorical Variable

# %%
data['Country'].value_counts()
# Out:
# New Zealand     5
# SriLanka        2
# Zimbabwe        1
# UAE             1
# South Africa    1
# Bandladesh      1
# Name: Country, dtype: int64

# %%
plt.hist(data['Country'])
plt.title("Country Wise")
plt.xlabel("Country")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(data['Ground'])
plt.title("Grount Category")
plt.xlabel("Ground")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(data['Opposition_Others'])
plt.xlabel("Opposition_Others")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Univariates Numerical Variable

# %%
plt.boxplot(data['ConsecutiveWins'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c407bc0160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c407bc0820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c407bb2eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c407bc0ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c407bcb280>],
#  'means': []}

# %%
plt.boxplot(data['ConsecutiveWins'].value_counts())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c407c21700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c407c21dc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c407c213a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c407c2b4c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c407c2b820>],
#  'means': []}

# %%
plt.plot(data['ConsecutiveWins'])

# %%
plt.plot(data['ConsecutiveWins'].value_counts())

# %%
data['ConsecutiveWins'].value_counts()
# Out:
# 0    6
# 1    2
# 4    1
# 3    1
# 2    1
# Name: ConsecutiveWins, dtype: int64

# %% [markdown]
# ### Handling Missing Values

# %%
missing=['A','B']
data=pd.read_csv('Cricket.csv',na_values=missing)
##Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns',None)
#Set it to None to display all rows in the dataframe
pd.set_option('display.max_rows',None)

# %%
data
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0               0.0  Summer       New Zealand   New Zealand      Wellington
# 1               0.0  Summer       New Zealand  South Africa      Queenstown
# 2               0.0  Summer       New Zealand   New Zealand    Christchurch
# 3               1.0  Summer       New Zealand   New Zealand          Napier
# 4               2.0  Summer       New Zealand   New Zealand        Hamilton
# 5               3.0  Summer       New Zealand   New Zealand        Auckland
# 6               0.0  Winter            Others      SriLanka      Hambantota
# 7               1.0  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8               2.0  Spring            Others      SriLanka   Colombo (RPS)
# 9               3.0  Autumn       New Zealand      SriLanka       Pallekele
# 10              NaN  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
List=['Yes','No',np.nan]

# %%
cnt=0
for row in data['Pak_Win']:
    if row in List:
        cnt+=1
        pass
    else:
        data.loc[cnt,'Pak_Win']=np.nan 
        cnt+=1

# %%
print(data['Pak_Win'].isnull().sum())
# Out:
# 3

# %%
print(data.isnull().sum())
# Out:
# ConsecutiveWins          2
# Season                   1
# Opposition_Others        1
# Country                  0
# Ground                   0
# Home_Ground              1
# Day_Night                0
# PitchReport              0
# BattingFirst             1
# Combination Changed     83
# Pak_Win                  3
# dtype: int64

# %%
print(data.isnull().sum().sum())
# Out:
# 92

# %%
data
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0               0.0  Summer       New Zealand   New Zealand      Wellington
# 1               0.0  Summer       New Zealand  South Africa      Queenstown
# 2               0.0  Summer       New Zealand   New Zealand    Christchurch
# 3               1.0  Summer       New Zealand   New Zealand          Napier
# 4               2.0  Summer       New Zealand   New Zealand        Hamilton
# 5               3.0  Summer       New Zealand   New Zealand        Auckland
# 6               0.0  Winter            Others      SriLanka      Hambantota
# 7               1.0  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8               2.0  Spring            Others      SriLanka   Colombo (RPS)
# 9               3.0  Autumn       New Zealand      SriLanka       Pallekele
# 10              NaN  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
data.shape
# Out:
# (95, 11)

# %%
data.loc[10,'ConsecutiveWins']=2
data.loc[24,'ConsecutiveWins']=7

# %%
print(data.isnull().sum())
# Out:
# ConsecutiveWins         0
# Season                  0
# Opposition_Others       0
# Country                 0
# Ground                  0
# Home_Ground             0
# Day_Night               0
# PitchReport             0
# BattingFirst            0
# Combination Changed     0
# Pak_Win                 0
# dtype: int64

# %% [markdown]
# ### Change DataTypes

# %%
data['ConsecutiveWins']=data['ConsecutiveWins'].astype(int)
data['ConsecutiveWins'].dtypes
# Out:
# dtype('int32')

# %%
data['Country']=data['Country'].astype('category')
data['Country'].dtypes
# Out:
# CategoricalDtype(categories=['Bandladesh', 'England', 'India', 'New Zealand', 'Others',
#                   'South Africa', 'SriLanka', 'UAE', 'West Indies',
#                   'Zimbabwe'],
#                  ordered=False)

# %%
data['Opposition_Others']=data['Opposition_Others'].astype('category')
data['Opposition_Others'].dtypes
# Out:
# CategoricalDtype(categories=['Australia', 'Bangladesh', 'England', 'India', 'New Zealand',
#                   'Others', 'South Africa', 'Sri Lanka', 'West Indies',
#                   'Zimbabwe'],
#                  ordered=False)

# %%
data['Ground']=data['Ground'].astype('category')
data['Ground'].dtypes
# Out:
# CategoricalDtype(categories=['Abu Dhabi', 'Auckland', 'Belfast', 'Benoni', 'Birmingham',
#                   'Bloemfontein', 'Bridgetown', 'Bulawayo', 'Cape Town',
#                   'Centurion', 'Chennai', 'Chittagong', 'Christchurch',
#                   'Colombo (RPS)', 'Dambulla', 'Delhi', 'Dhaka', 'Dubai (DSC)',
#                   'Dublin', 'Durban', 'Edinburgh', 'Fatullah', 'Gros Islet',
#                   'Hambantota', 'Hamilton', 'Harare', 'Johannesburg',
#                   'Kolkata', 'Mohali', 'Napier', 'Pallekele', 'Port Elizabeth',
#                   'Providence', 'Queenstown', 'Sharjah', 'The Oval',
#                   'Wellington'],
#                  ordered=False)

# %%
data['Season'].fillna(data['Season'].mode()[0], inplace=True)

# %%
data['Opposition_Others'].fillna(data['Opposition_Others'].mode()[0], inplace=True)

# %%
data['Home_Ground'].fillna(data['Home_Ground'].mode()[0], inplace=True)

# %%
data['BattingFirst'].fillna(data['BattingFirst'].mode()[0], inplace=True)

# %%
data['Pak_Win'].fillna(data['Pak_Win'].mode()[0], inplace=True)

# %%
data['Combination Changed '].fillna(data['Combination Changed '].mode()[0], inplace=True)

# %%
data
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0                 0  Summer       New Zealand   New Zealand      Wellington
# 1                 0  Summer       New Zealand  South Africa      Queenstown
# 2                 0  Summer       New Zealand   New Zealand    Christchurch
# 3                 1  Summer       New Zealand   New Zealand          Napier
# 4                 2  Summer       New Zealand   New Zealand        Hamilton
# 5                 3  Summer       New Zealand   New Zealand        Auckland
# 6                 0  Winter            Others      SriLanka      Hambantota
# 7                 1  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8                 2  Spring            Others      SriLanka   Colombo (RPS)
# 9                 3  Autumn       New Zealand      SriLanka       Pallekele
# 10                2  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
print(data.isnull().sum())
# Out:
# ConsecutiveWins         0
# Season                  0
# Opposition_Others       0
# Country                 0
# Ground                  0
# Home_Ground             0
# Day_Night               0
# PitchReport             0
# BattingFirst            0
# Combination Changed     0
# Pak_Win                 0
# dtype: int64

# %%
print(data.isnull().sum().sum())
# Out:
# 0

# %%
data.shape
# Out:
# (95, 11)

# %%
df2
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0               0.0  Summer       New Zealand   New Zealand      Wellington
# 1               0.0  Summer       New Zealand  South Africa      Queenstown
# 2               0.0  Summer       New Zealand   New Zealand    Christchurch
# 3               1.0  Summer       New Zealand   New Zealand          Napier
# 4               2.0  Summer       New Zealand   New Zealand        Hamilton
# 5               3.0  Summer       New Zealand   New Zealand        Auckland
# 6               0.0  Winter            Others      SriLanka      Hambantota
# 7               1.0  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8               2.0  Spring            Others      SriLanka   Colombo (RPS)
# 9               3.0  Autumn       New Zealand      SriLanka       Pallekele
# 10              NaN  Autumn          Zimbabwe      SriLanka       Pallekele
# ...

# %%
df2.shape
# Out:
# (95, 11)

# %%
df2.fillna(df2.mode(), inplace=True)

# %% [markdown]
# ##### Data Quality  Issues..problem of data quality, to ensure data quality system in Big Data environment, and try to find out the data ... Therefore, you need to unify the data format and remove empty data and also correct the invalid data in a given data set.these are the issue like blanks,Nulls. Outliers,Duplicates,Extra spaces.Misspellings data.how are handle this data issue are more compilcated to resolve these issue.Its take more time consuming.its a very difficult to me that how i resovle the nan data and incorrect data.i have more learned the data handling.

# %%
df2
# Out:
#     ConsecutiveWins  Season Opposition_Others       Country          Ground  \
# 0           0.00000  Summer       New Zealand   New Zealand      Wellington
# 1           0.00000  Summer       New Zealand  South Africa      Queenstown
# 2           0.00000  Summer       New Zealand   New Zealand    Christchurch
# 3           1.00000  Summer       New Zealand   New Zealand          Napier
# 4           2.00000  Summer       New Zealand   New Zealand        Hamilton
# 5           3.00000  Summer       New Zealand   New Zealand        Auckland
# 6           0.00000  Winter            Others      SriLanka      Hambantota
# 7           1.00000  Winter         Sri Lanka      SriLanka   Colombo (RPS)
# 8           2.00000  Spring            Others      SriLanka   Colombo (RPS)
# 9           3.00000  Autumn       New Zealand      SriLanka       Pallekele
# 10          1.11828  Autumn          Zimbabwe      SriLanka       Pallekele
# ...
